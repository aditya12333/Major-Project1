# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\adity\\Downloads\\Dataset\\credit card.csv')

# %%
df.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...

# %% [markdown]
# ### Data Description

# %% [markdown]
# The columns stands for:
#
# **ID:** *ID of each client*
#
# **LIMIT_BAL:** *Amount of given credit in NT dollars (includes individual and family/supplementary credit)*
#
# **SEX:** *Gender (1=male, 2=female)*
#
# **EDUCATION:** *(1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)*
#
# **MARRIAGE:** *Marital status (1=married, 2=single, 3=others)*
#
# **AGE:** *Age in years*
#
# **PAY_0:** *Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, …             8=payment delay for eight months, 9=payment delay for nine months and above)*
#
# **PAY_2:** *Repayment status in August, 2005 (scale same as above)*
#
# **PAY_3:** *Repayment status in July, 2005 (scale same as above)*
#
# **PAY_4:** *Repayment status in June, 2005 (scale same as above)*
#
# **PAY_5:** *Repayment status in May, 2005 (scale same as above)*
#
# **PAY_6:** *Repayment status in April, 2005 (scale same as above)*
#
# **BILL_AMT1:** *Amount of bill statement in September, 2005 (NT dollar)*
#
# **BILL_AMT2:** *Amount of bill statement in August, 2005 (NT dollar)*
#
# **BILL_AMT3:** *Amount of bill statement in July, 2005 (NT dollar)*
#
# **BILL_AMT4:** *Amount of bill statement in June, 2005 (NT dollar)*
#
# **BILL_AMT5:** *Amount of bill statement in May, 2005 (NT dollar)*
#
# **BILL_AMT6:** *Amount of bill statement in April, 2005 (NT dollar)*
#
# **PAY_AMT1:** *Amount of previous payment in September, 2005 (NT dollar)*
#
# **PAY_AMT2:** *Amount of previous payment in August, 2005 (NT dollar)*
#
# **PAY_AMT3:** *Amount of previous payment in July, 2005 (NT dollar)*
#
# **PAY_AMT4:** *Amount of previous payment in June, 2005 (NT dollar)*
#
# **PAY_AMT5:** *Amount of previous payment in May, 2005 (NT dollar)*
#
# **PAY_AMT6:** *Amount of previous payment in April, 2005 (NT dollar)
#
# **default_payment** (1=yes, 0=no)

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# ### Null Values Checking

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# **'ID'** column doesn't hold any importance for further analysis. So, can be dropped.

# %%
df=df.drop('ID', axis=1)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %% [markdown]
# ### Renaming some columns

# %%
df.rename(columns = {"PAY_0": "September Repayment Status", "PAY_2": "August Repayment Status", 
                     "PAY_3": "July Repayment Status", "PAY_4": "June Repayment Status",
                     "PAY_5": "May Repayment Status", "PAY_6": "April Repayment Status"}, inplace=True)

df.rename(columns = {"BILL_AMT1": "September bill statement", "BILL_AMT2": "August bill statement", 
                     "BILL_AMT3": "July bill statement", "BILL_AMT4": "June bill statement", "BILL_AMT5": "May bill statement", 
                     "BILL_AMT6": "April bill statement"}, inplace=True)

df.rename(columns = {"PAY_AMT1": "September previous Payment", "PAY_AMT2": "August previous Payment",
                     "PAY_AMT3": "July previous Payment", "PAY_AMT4": "June previous payment",
                     "PAY_AMT5": "May previous payment", "PAY_AMT6": "April previous payment", 
                     "default.payment.next.month": "Default Payment"}, inplace=True)

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'September Repayment Status', 'August Repayment Status',
#        'July Repayment Status', 'June Repayment Status',
#        'May Repayment Status', 'April Repayment Status',
#        'September bill statement', 'August bill statement',
#        'July bill statement', 'June bill statement', 'May bill statement',
#        'April bill statement', 'September previous Payment',
#        'August previous Payment', 'July previous Payment',
#        'June previous payment', 'May previous payment',
#        'April previous payment', 'Default Payment'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Marriage

# %% [markdown]
# There are 3 categories in marriage. 1, 2 & 3 but there is 0 present. Need to impute or delete it

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# Only 54 numbers of 0s are there. So those can be removed.

# %% [markdown]
# Replacing 0s with null values and then drop them

# %%
df.drop(df[df['MARRIAGE'] == 0].index, inplace=True)

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# 'MARRIAGE' column has been cleaned

# %% [markdown]
# ### Education

# %% [markdown]
# In this column has 6 attributes but 5 & 6 means the same. So, it is futile to continue with two different attributes for the same purpose.

# %%
df['EDUCATION'].value_counts()
# Out:
# 2    14024
# 1    10581
# 3     4873
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %% [markdown]
# Now in this column we have **14** 0s which can be removed. As, there are only **51** 6s, we can just remove it

# %%
df.drop(df[df['EDUCATION'] == 0].index, inplace=True)

# %%
df.drop(df[df['EDUCATION'] == 6].index, inplace=True)

# %%
df['EDUCATION'].value_counts()
# Out:
# 2    14024
# 1    10581
# 3     4873
# 5      280
# 4      123
# Name: EDUCATION, dtype: int64

# %% [markdown]
# 'EDUCATION' column is now cleaned

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Number of Male & Female

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "SEX", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# We got more **Female** customers than **Male**

# %% [markdown]
# ### Marriage

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "MARRIAGE", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Majority of the customers are **Single** followed by **Married Couples**

# %% [markdown]
# ### Education

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "EDUCATION", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Most of the customers are University Student/Passout followed by people of school graduate

# %% [markdown]
# ### Checking the distribution for 'LIMIT_BAL' & 'AGE'

# %%
plt.figure(figsize = (7,6))
sns.distplot(df['LIMIT_BAL'], bins = 20)

plt.figure(figsize = (7,6))
sns.distplot(df['AGE'], bins = 20)

plt.show()

# %% [markdown]
# ### Number of Defaulters

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "Default Payment", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Majority of the customers don't default.

# %% [markdown]
# ### Number of Defaulter between Male & Female

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "Default Payment", hue="SEX", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# There are more Female defaulters than Male.

# %% [markdown]
# ### Number of Defaulters with respect to Marital Status

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "Default Payment", hue="MARRIAGE", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### Number of Defaulters with respect to Education

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "Default Payment", hue="EDUCATION", data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
x = df.drop(['Default Payment'], axis = 1)
y = df["Default Payment"]

# %%
# scaling the feature
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(x)
# Out:
# array([[-1.13665097,  0.81016956,  0.20068741, ..., -0.30787923,
#         -0.31477227, -0.2936223 ],
#        [-0.36633415,  0.81016956,  0.20068741, ..., -0.24413063,
#         -0.31477227, -0.18081221],
#        [-0.5974292 ,  0.81016956,  0.20068741, ..., -0.24413063,
#         -0.24910602, -0.01159707],
#        ...,
#        [-1.05961929, -1.23430951,  0.20068741, ..., -0.04013509,
#         -0.18343977, -0.11876665],
#        [-0.67446088, -1.23430951,  1.49812155, ..., -0.18509942,
#          3.16317502, -0.19186759],
#        [-0.90555593, -1.23430951,  0.20068741, ..., -0.24413063,
#         -0.24910602, -0.23721725]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 1)

# %% [markdown]
# ## Oversampling

# %%
#!pip install imblearn
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(0.75)
x_res, y_res = oversample.fit_resample(x_train, y_train)
print(x_res.shape,y_res.shape)
# Out:
# (30514, 23) (30514,)
# C:\Users\adity\anaconda3\lib\site-packages\imblearn\utils\_validation.py:586: FutureWarning: Pass sampling_strategy=0.75 as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn(

# %%
# Count the number of classes 
from collections import Counter
print("The number of classes before fit {}".format(Counter(y)))
print("The number of classes after fit {}".format(Counter(y_res)))
# Out:
# The number of classes before fit Counter({0: 23258, 1: 6623})
# The number of classes after fit Counter({0: 17437, 1: 13077})

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = y_res, data=df)
plt.xticks(fontsize=12, rotation=0)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Lg = LogisticRegression()
Lg.fit(x_train, y_train)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Lg_pred = Lg.predict(x_test)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, Lg_pred))
print(metrics.roc_auc_score(y_test,Lg_pred))
print(metrics.confusion_matrix(y_test, Lg_pred))
print(metrics.classification_report(y_test, Lg_pred))
# Out:
# 0.7791460313211083
# 0.5
# [[5821    0]
#  [1650    0]]
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      5821
#            1       0.00      0.00      0.00      1650
#
#     accuracy                           0.78      7471
#    macro avg       0.39      0.50      0.44      7471
# weighted avg       0.61      0.78      0.68      7471
# C:\Users\adity\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\adity\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_res, y_res)
rf_pred = rf.predict(x_test)

# %%
print(metrics.accuracy_score(y_test, rf_pred))
print(metrics.roc_auc_score(y_test, rf_pred))
print(metrics.confusion_matrix(y_test, rf_pred))
print(metrics.classification_report(y_test, rf_pred))
# Out:
# 0.8107348413866953
# 0.666185753775515
# [[5385  436]
#  [ 978  672]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.88      5821
#            1       0.61      0.41      0.49      1650
#
#     accuracy                           0.81      7471
#    macro avg       0.73      0.67      0.69      7471
# weighted avg       0.79      0.81      0.80      7471

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_res, y_res)
nb_pred = nb.predict(x_test)

# %%
print(metrics.accuracy_score(y_test, nb_pred))
print(metrics.roc_auc_score(y_test, nb_pred))
print(metrics.confusion_matrix(y_test, nb_pred))
print(metrics.classification_report(y_test, nb_pred))
# Out:
# 0.33369026904028914
# 0.5470055129546626
# [[ 960 4861]
#  [ 117 1533]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.16      0.28      5821
#            1       0.24      0.93      0.38      1650
#
#     accuracy                           0.33      7471
#    macro avg       0.57      0.55      0.33      7471
# weighted avg       0.75      0.33      0.30      7471

# %% [markdown]
# ##  SVM

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_res, y_res)
svc_pred = nb.predict(x_test)

print(metrics.accuracy_score(y_test, svc_pred))
print(metrics.roc_auc_score(y_test, svc_pred))
print(metrics.confusion_matrix(y_test, svc_pred))
print(metrics.classification_report(y_test, svc_pred))
# Out:
# 0.33369026904028914
# 0.5470055129546626
# [[ 960 4861]
#  [ 117 1533]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.16      0.28      5821
#            1       0.24      0.93      0.38      1650
#
#     accuracy                           0.33      7471
#    macro avg       0.57      0.55      0.33      7471
# weighted avg       0.75      0.33      0.30      7471

# %% [markdown]
# ## XGB

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(x_res, y_res)
xgb_pred = nb.predict(x_test)

print(metrics.accuracy_score(y_test, xgb_pred))
print(metrics.roc_auc_score(y_test, xgb_pred))
print(metrics.confusion_matrix(y_test, xgb_pred))
print(metrics.classification_report(y_test, xgb_pred))
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [02:21:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.33369026904028914
# 0.5470055129546626
# [[ 960 4861]
#  [ 117 1533]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.16      0.28      5821
# ...

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_res, y_res)
knn_pred = knn.predict(x_test)

print(metrics.accuracy_score(y_test, knn_pred))
print(metrics.roc_auc_score(y_test, knn_pred))
print(metrics.confusion_matrix(y_test, knn_pred))
print(metrics.classification_report(y_test, knn_pred))
# Out:
# 0.6340516664435818
# 0.5745166143482584
# [[3965 1856]
#  [ 878  772]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.68      0.74      5821
#            1       0.29      0.47      0.36      1650
#
#     accuracy                           0.63      7471
#    macro avg       0.56      0.57      0.55      7471
# weighted avg       0.70      0.63      0.66      7471

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_res, y_res)
dt_pred = dt.predict(x_test)

print(metrics.accuracy_score(y_test, dt_pred))
print(metrics.roc_auc_score(y_test, dt_pred))
print(metrics.confusion_matrix(y_test, dt_pred))
print(metrics.classification_report(y_test, dt_pred))
# Out:
# 0.7329674742337037
# 0.6112861478554658
# [[4827  994]
#  [1001  649]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      5821
#            1       0.40      0.39      0.39      1650
#
#     accuracy                           0.73      7471
#    macro avg       0.61      0.61      0.61      7471
# weighted avg       0.73      0.73      0.73      7471

# %%
import pickle
with open('Credit_Card_default_pickle_RF_final','wb') as f:
    pickle.dump(rf, f)

# %%
rf_pred_2 = rf.predict(np.array([20000,
     2,
     2,
     2,
     34,
     0,
     0,
     0,
     0,
     0,
     0,
     29239,
     14027,
     13559,
     14331,
     14948,
     15549,
     1518,
     1500,
     1000,
     1000,
     1000,
     5000]).reshape(1,-1))
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
rf_pred_2
# Out:
# array([0], dtype=int64)

# %%
rf_pred_1 = rf.predict(np.array([20000,
2,
2,
1,
24,
2,
2,
-1,
-1,
-2,
-2,
3913,
3102,
689,
0,
0,
0,
0,
689,
0,
0,
0,
0]).reshape(1, -1))
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
rf_pred_1
# Out:
# array([1], dtype=int64)
